# %% [markdown]
# Collect --------------------------------------------------------------------------------

# %% [markdown]
# Import csv and convert to df

# %%
import pandas as pd

# Collect
df = pd.read_csv('E:\\Visualstudio\\Data_analysis_projects\\Data_analysis_process\\Resources\\Solar_Energy_Production.csv')
df
# Out:
#                                   name      id                   address  \
# 0       Calgary Fire Hall Headquarters  314106             1212 42 AV SE
# 1       Calgary Fire Hall Headquarters  314106             1212 42 AV SE
# 2       Calgary Fire Hall Headquarters  314106             1212 42 AV SE
# 3       Calgary Fire Hall Headquarters  314106             1212 42 AV SE
# 4       Calgary Fire Hall Headquarters  314106             1212 42 AV SE
# ...                                ...     ...                       ...
# 258418  Bearspaw Water Treatment Plant  577650  11444 Bearspaw Dam RD NW
# 258419  Bearspaw Water Treatment Plant  577650  11444 Bearspaw Dam RD NW
# 258420  Bearspaw Water Treatment Plant  577650  11444 Bearspaw Dam RD NW
# 258421  Bearspaw Water Treatment Plant  577650  11444 Bearspaw Dam RD NW
# 258422  Bearspaw Water Treatment Plant  577650  11444 Bearspaw Dam RD NW
#
#                           date      kWh  \
# 0       2017/09/11 08:00:00 AM    1.130
# ...

# %% [markdown]
# Analyze -----------------------------------------------------------------------------------

# %%
import pandas as pd

# Collect
df = pd.read_csv('E:\\Visualstudio\\Data_analysis_projects\\Data_analysis_process\\Resources\\Solar_Energy_Production.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258423 entries, 0 to 258422
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              258423 non-null  object
#  1   id                258423 non-null  int64
#  2   address           258423 non-null  object
#  3   date              258423 non-null  object
#  4   kWh               258423 non-null  float64
#  5   public_url        258423 non-null  object
#  6   installationDate  258423 non-null  object
#  7   uid               258423 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 15.8+ MB

# %% [markdown]
# See how many names with same types are

# %%
import pandas as pd

# Collect
df = pd.read_csv('E:\\Visualstudio\\Data_analysis_projects\\Data_analysis_process\\Resources\\Solar_Energy_Production.csv')
#df

# Get the frequency of each unique value in the 'name' column
name_counts = df['name'].value_counts()

# Print the result
name_counts
# Out:
# Southland Leisure Centre                     31590
# Whitehorn Multi-Service Centre               27716
# City of Calgary North Corporate Warehouse    27092
# Richmond - Knob Hill Community Hall          26623
# Glenmore Water Treatment Plant               25920
# Calgary Fire Hall Headquarters               25637
# Bearspaw Water Treatment Plant               24869
# Hillhurst Sunnyside Community Association    23467
# CFD Firehall #7                              22659
# Manchester Building M                        22533
# Telus Spark                                    317
# Name: name, dtype: int64

# %% [markdown]
# Extract data from one same type name

# %%
import pandas as pd

# Collect
df = pd.read_csv('E:\\Visualstudio\\Data_analysis_projects\\Data_analysis_process\\Resources\\Solar_Energy_Production.csv')

# Use boolean indexing to extract rows with the name 'Charlie'
slc = df[df.loc[:,('name')] == 'Southland Leisure Centre']
slc.head(3)
# Out:
#                          name      id               address  \
# 148  Southland Leisure Centre  164440  2000 SOUTHLAND DR SW
# 149  Southland Leisure Centre  164440  2000 SOUTHLAND DR SW
# 150  Southland Leisure Centre  164440  2000 SOUTHLAND DR SW
#
#                        date     kWh  \
# 148  2017/09/06 07:00:00 AM   3.663
# 149  2017/09/06 08:00:00 AM  16.378
# 150  2017/09/06 09:00:00 AM  37.839
#
#                                             public_url installationDate  \
# 148  https://monitoring.solaredge.com/solaredge-web...       2015/09/01
# 149  https://monitoring.solaredge.com/solaredge-web...       2015/09/01
# 150  https://monitoring.solaredge.com/solaredge-web...       2015/09/01
#
#                            uid
# 148  1644402017-09-06 07:00:00
# 149  1644402017-09-06 08:00:00
# 150  1644402017-09-06 09:00:00

# %% [markdown]
# Share ------------------------------------------------------------------------------------

# %% [markdown]
# Create a graph from one company that gets the total kWh produced by year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Collect
df = pd.read_csv('E:\\Visualstudio\\Data_analysis_projects\\Data_analysis_process\\Resources\\Solar_Energy_Production.csv')

# Convert the date column to a datetime format and assign it to a new column:
df.loc[:, 'datetime'] = pd.to_datetime(df['date'], format='%Y/%m/%d %I:%M:%S %p')

# Create a new column for the year:
df.loc[:, 'Year'] = df['datetime'].dt.year

# Use boolean indexing to extract rows with the name 'Southland Leisure Centre'
slc = df[df.loc[:,'name'] == 'Southland Leisure Centre']

# Group the DataFrame by year and calculate the sum of the kWh column for each year
df_grouped = slc.groupby('Year')['kWh'].sum().reset_index()

# Create a bar graph using matplotlib
plt.bar(df_grouped['Year'], df_grouped['kWh'])
plt.xlabel('Year')
plt.ylabel('kWh')
plt.title('Total kWh by Year from: Southland Leisure Centre')
plt.show()
