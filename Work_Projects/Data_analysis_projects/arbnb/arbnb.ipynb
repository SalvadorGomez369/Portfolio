# %% [markdown]
# Collect --------------------------------------------------------------------------------

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('E:\\Visualstudio\\Work_Projects\\Data_analysis_projects\\arbnb\Resources\\Aemf1.csv')

df
# Out:
#             City       Price      Day        Room Type  Shared Room  \
# 0      Amsterdam  194.033698  Weekday     Private room        False
# 1      Amsterdam  344.245776  Weekday     Private room        False
# 2      Amsterdam  264.101422  Weekday     Private room        False
# 3      Amsterdam  433.529398  Weekday     Private room        False
# 4      Amsterdam  485.552926  Weekday     Private room        False
# ...          ...         ...      ...              ...          ...
# 41709     Vienna  715.938574  Weekend  Entire home/apt        False
# 41710     Vienna  304.793960  Weekend  Entire home/apt        False
# 41711     Vienna  637.168969  Weekend  Entire home/apt        False
# 41712     Vienna  301.054157  Weekend     Private room        False
# 41713     Vienna  133.230489  Weekend     Private room        False
#
#        Private Room  Person Capacity  Superhost  Multiple Rooms  Business  \
# 0              True              2.0      False               1         0
# ...

# %% [markdown]
# Analyze -----------------------------------------------------------------------------------

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('E:\\Visualstudio\\Work_Projects\\Data_analysis_projects\\arbnb\\Resources\\Aemf1.csv')

# Print info of the DataFrame
df.info() #print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41714 entries, 0 to 41713
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   City                         41714 non-null  object
#  1   Price                        41714 non-null  float64
#  2   Day                          41714 non-null  object
#  3   Room Type                    41714 non-null  object
#  4   Shared Room                  41714 non-null  bool
#  5   Private Room                 41714 non-null  bool
#  6   Person Capacity              41714 non-null  float64
#  7   Superhost                    41714 non-null  bool
#  8   Multiple Rooms               41714 non-null  int64
#  9   Business                     41714 non-null  int64
#  10  Cleanliness Rating           41714 non-null  float64
#  11  Guest Satisfaction           41714 non-null  float64
#  12  Bedrooms                     41714 non-null  int64
# ...

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('E:\\Visualstudio\\Work_Projects\\Data_analysis_projects\\arbnb\\Resources\\Aemf1.csv')

# Get the frequency of each unique value in the 'name' column
name_counts = df['City'].value_counts()

# Print the result
name_counts
# Out:
# Rome         9027
# Paris        6688
# Lisbon       5763
# Athens       5280
# Budapest     4022
# Vienna       3537
# Barcelona    2833
# Berlin       2484
# Amsterdam    2080
# Name: City, dtype: int64

# %% [markdown]
# Share ------------------------------------------------------------------------------------

# %% [markdown]
# Gets the mean of paris columns

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df = pd.read_csv('E:\\Visualstudio\\Work_Projects\\Data_analysis_projects\\arbnb\\Resources\\Aemf1.csv')

# Use boolean indexing to extract rows with the name 'Southland Leisure Centre'
slc = df[df.loc[:,'City'] == 'Paris']

p = slc.mean(numeric_only=True)
# slc.median(numeric_only=True)
# slc.mode(numeric_only=True)


# create a bar graph
p.plot(kind='barh')

# add title and axis labels
plt.title('Paris mean')
plt.xlabel('Mean')
plt.ylabel('Value')

# rotate x-axis labels for better visibility
#plt.xticks(rotation=0)

# display the plot
plt.show()

# %% [markdown]
# Gets the median of paris columns

# %%
# median
slc.median(numeric_only=True)
# Out:
# Price                          317.597167
# Shared Room                      0.000000
# Private Room                     0.000000
# Person Capacity                  2.000000
# Superhost                        0.000000
# Multiple Rooms                   0.000000
# Business                         0.000000
# Cleanliness Rating               9.000000
# Guest Satisfaction              94.000000
# Bedrooms                         1.000000
# City Center (km)                 2.997026
# Metro Distance (km)              0.207317
# Attraction Index               337.941264
# Normalised Attraction Index     16.448810
# Restraunt Index                771.165470
# Normalised Restraunt Index      40.373716
# dtype: float64

# %% [markdown]
# Gets the mode of paris columns

# %%
# mode
slc.mode(numeric_only=True).iloc[0]
# Out:
# Price                          278.217914
# Shared Room                         False
# Private Room                        False
# Person Capacity                       2.0
# Superhost                           False
# Multiple Rooms                        0.0
# Business                              0.0
# Cleanliness Rating                   10.0
# Guest Satisfaction                  100.0
# Bedrooms                              1.0
# City Center (km)                 0.071543
# Metro Distance (km)               0.00322
# Attraction Index               116.297506
# Normalised Attraction Index         100.0
# Restraunt Index                  258.6744
# Normalised Restraunt Index          100.0
# Name: 0, dtype: object

# %% [markdown]
# Max and Min

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('E:\\Visualstudio\\Work_Projects\\Data_analysis_projects\\arbnb\\Resources\\Aemf1.csv')

# Use boolean indexing to extract rows with the name 'Southland Leisure Centre'
slc = df[df.loc[:,'City'] == 'Paris']

# Gets max and min values from the city Paris
numeric_columns = slc.select_dtypes(include='number')
max_values = numeric_columns.max()
min_values = numeric_columns.min()

# max values
# print("\nMaximum values:\n", max_values)
# print("Minimum values:\n", min_values)


# create a bar graph
max_values.plot(kind='barh')

# add title and axis labels
plt.title('Paris Max values')
plt.xlabel('Max')
plt.ylabel('Value')

# rotate x-axis labels for better visibility
#plt.xticks(rotation=0)

# display the plot
plt.show()

# %%
# min values
# print("Minimum values:\n", min_values)


# create a bar graph
min_values.plot(kind='barh')

# add title and axis labels
plt.title('Paris Min values')
plt.xlabel('Min')
plt.ylabel('Value')

# rotate x-axis labels for better visibility
#plt.xticks(rotation=0)

# display the plot
plt.show()

# %% [markdown]
# Correlation matrix graph

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df = pd.read_csv('E:\\Visualstudio\\Work_Projects\\Data_analysis_projects\\arbnb\\Resources\\Aemf1.csv')

# drop the 'RowNumber' and 'CustomerId' columns
# df = df.drop(['RowNumber', 'CustomerId'], axis=1)

# create a correlation matrix
corr_matrix = df.corr(numeric_only=True)

# round the values to 2 decimal places
corr_matrix = corr_matrix.round(1)

# create a heatmap of the correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

# add title
plt.title('Correlation Matrix')

# display the plot
plt.show()

# %% [markdown]
# The Attraction Index: is a measure of the overall attractiveness of a location, taking into account factors such as proximity to public transportation, schools, shopping centers, parks, and other amenities.
# The Normalised Attraction Index: is a version of this measure that has been standardized or normalized to allow for comparison across different locations.
#
# The Restaurant Index: is a measure of the number and quality of restaurants in a particular area, which can be an important factor for renters who enjoy dining out or want convenient access to food options.
# The Normalised Restaurant Index: is a standardized version of this measure.
#
# By considering factors such as the Attraction Index and Restaurant Index, landlords or property managers can make informed decisions about rental rates, marketing strategies, and other aspects of managing rental properties. Likewise, potential renters can use this information to help them evaluate different locations and neighborhoods to find the best fit for their needs and preferences.
