# %%
# object.method(attributes)
"hello".center(10, "-") # "--hello---" Centers the string within a 10-character wide field, padding with "-")
# Out:
# '--hello---'

# %%
import pandas as pd

# The list of tuples
methods_examples = [
    ('"hello".capitalize()', '"Hello"', 'Capitalizes the first letter of the string.'),
    ('"HELLO".casefold()', '"hello"', 'Converts the string to lowercase for case-insensitive comparison.'),
    ('"hello".center(10, "-")', '"--hello---"', 'Centers the string within a 10-character wide field, padding with \'-\'.'),
    ('"hello world".count("o")', '2', 'Counts occurrences of the letter "o" in the string.'),
    ('"hello".encode()', "b'hello'", 'Encodes the string into bytes using the default UTF-8 encoding.'),
    ('"hello".endswith("lo")', 'True', 'Checks if the string ends with the substring "lo".'),
    ('"hello\\tworld".expandtabs(4)', '"hello   world"', 'Replaces tabs with spaces (4 spaces per tab).'),
    ('"hello".find("e")', '1', 'Finds the index of the first occurrence of "e".'),
    ('"Hello, {}!".format("Alice")', '"Hello, Alice!"', 'Inserts the value "Alice" into the string at the placeholder.'),
    ('"Hello, {name}!".format_map({"name": "Bob"})', '"Hello, Bob!"', 'Similar to format, but uses a dictionary to map values.'),
    ('"hello".index("l")', '2', 'Finds the index of the first occurrence of "l" (raises ValueError if not found).'),
    ('"hello123".isalnum()', 'True', 'Checks if the string consists only of alphanumeric characters.'),
    ('"hello".isalpha()', 'True', 'Checks if the string consists only of alphabetic characters.'),
    ('"hello".isascii()', 'True', 'Checks if all characters in the string are ASCII.'),
    ('"12345".isdecimal()', 'True', 'Checks if the string consists only of decimal characters.'),
    ('"12345".isdigit()', 'True', 'Checks if the string consists only of digits.'),
    ('"hello".isidentifier()', 'True', 'Checks if the string is a valid Python identifier.'),
    ('"hello".islower()', 'True', 'Checks if all characters in the string are lowercase.'),
    ('"12345".isnumeric()', 'True', 'Checks if the string consists only of numeric characters.'),
    ('"hello".isprintable()', 'True', 'Checks if all characters in the string are printable.'),
    ('"   ".isspace()', 'True', 'Checks if the string consists only of whitespace characters.'),
    ('"Hello World".istitle()', 'True', 'Checks if the string is a title (each word starts with a capital letter).'),
    ('"HELLO".isupper()', 'True', 'Checks if all characters in the string are uppercase.'),
    ('" ,".join(["a", "b", "c"])', '"a,b,c"', 'Joins the elements of a list into a string with commas separating them.'),
    ('"hello".ljust(10, "-")', '"hello-----"', 'Left-justifies the string within a 10-character wide field, padding with \'-\'.'),
    ('"HELLO".lower()', '"hello"', 'Converts all characters in the string to lowercase.'),
    ('"  hello".lstrip()', '"hello"', 'Removes leading whitespace from the string.'),
    ('"hello".maketrans("h", "y")', '{104: 121}', 'Creates a translation table for replacing characters.'),
    ('"hello world".partition(" ")', "('hello', ' ', 'world')", 'Splits the string at the first occurrence of " ".'),
    ('"hello world".replace("world", "there")', '"hello there"', 'Replaces "world" with "there".'),
    ('"hello".rfind("l")', '3', 'Finds the index of the last occurrence of "l".'),
    ('"hello".rindex("l")', '3', 'Finds the index of the last occurrence of "l" (raises ValueError if not found).'),
    ('"hello".rjust(10, "-")', '"-----hello"', 'Right-justifies the string within a 10-character wide field, padding with \'-\'.'),
    ('"hello world".rpartition(" ")', "('hello', ' ', 'world')", 'Splits the string at the last occurrence of " ".'),
    ('"hello world".rsplit(" ")', "['hello', 'world']", 'Splits the string into a list from the right at each space.'),
    ('"hello  ".rstrip()', '"hello"', 'Removes trailing whitespace from the string.'),
    ('"hello world".split(" ")', "['hello', 'world']", 'Splits the string into a list at each space.'),
    ('"hello\\nworld".splitlines()', "['hello', 'world']", 'Splits the string into a list at each newline.'),
    ('"hello".startswith("he")', 'True', 'Checks if the string starts with the substring "he".'),
    ('"  hello  ".strip()', '"hello"', 'Removes leading and trailing whitespace from the string.'),
    ('"Hello".swapcase()', '"hELLO"', 'Swaps the case of all characters in the string.'),
    ('"hello world".title()', '"Hello World"', 'Capitalizes the first letter of each word in the string.'),
    ('"hello".translate("hello".maketrans("h", "y"))', '"yello"', 'Translates characters using the given translation table.'),
    ('"hello".upper()', '"HELLO"', 'Converts all characters in the string to uppercase.'),
    ('"42".zfill(5)', '"00042"', 'Pads the string with zeros on the left to make it 5 characters long.')
]

# Create a pandas DataFrame
df = pd.DataFrame(methods_examples, columns=['Method_example', 'Output', 'Description'])

# Display the DataFrame
df
# Out:
#                                     Method_example                   Output  \
# 0                             "hello".capitalize()                  "Hello"
# 1                               "HELLO".casefold()                  "hello"
# 2                          "hello".center(10, "-")             "--hello---"
# 3                         "hello world".count("o")                        2
# 4                                 "hello".encode()                 b'hello'
# 5                           "hello".endswith("lo")                     True
# 6                     "hello\tworld".expandtabs(4)          "hello   world"
# 7                                "hello".find("e")                        1
# 8                     "Hello, {}!".format("Alice")          "Hello, Alice!"
# 9     "Hello, {name}!".format_map({"name": "Bob"})            "Hello, Bob!"
# 10                              "hello".index("l")                        2
# ...
