# %%
# \r is used to move the cursor to the beginning of the line
txt = "Hello\rWorld\r!hsdaojd\rakoiwjjd8wu8\rdawdw"
print(txt)
# Out:
# dawdwjjd8wu8
